# %%
import pandas as pd
import numpy as np

# %%
cd ..
# Out:
# /Users/rashidbaset/code/mod3_project

# %%
# !pwd
# Out:
# /Users/rashidbaset/code/mod3_project/Notebooks

# %%
df1 = pd.read_csv('data/labels.csv') #target class dataset
df2 = pd.read_csv('data/values.csv') #features dataset

# %% [markdown]
# ### Merge

# %%
df = pd.merge(df1, df2, on='id', how='inner')
df
# Out:
#           id    status_group  amount_tsh date_recorded           funder  \
# 0      69572      functional      6000.0    2011-03-14            Roman
# 1       8776      functional         0.0    2013-03-06          Grumeti
# 2      34310      functional        25.0    2013-02-25     Lottery Club
# 3      67743  non functional         0.0    2013-01-28           Unicef
# 4      19728      functional         0.0    2011-07-13      Action In A
# ...      ...             ...         ...           ...              ...
# 59395  60739      functional        10.0    2013-05-03  Germany Republi
# 59396  27263      functional      4700.0    2011-05-07      Cefa-njombe
# 59397  37057      functional         0.0    2011-04-11              NaN
# 59398  31282      functional         0.0    2011-03-08            Malec
# 59399  26348      functional         0.0    2011-03-23       World Bank
#
#        gps_height     installer  longitude   latitude              wpt_name  \
# ...

# %% [markdown]
# ---
# ## Pre-cleaning Analysis

# %%
df.isna().sum()
# Out:
# id                           0
# status_group                 0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# ...

# %%
(df == 0).sum()
# Out:
# id                           1
# status_group                 0
# amount_tsh               41639
# date_recorded                0
# funder                       0
# gps_height               20438
# installer                    0
# longitude                 1812
# latitude                     0
# wpt_name                     0
# num_private              58643
# basin                        0
# subvillage                   0
# region                       0
# region_code                  0
# district_code               23
# lga                          0
# ward                         0
# population               21381
# public_meeting            5055
# recorded_by                  0
# scheme_management            0
# scheme_name                  0
# permit                   17492
# construction_year        20709
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# ...

# %% [markdown]
# ---
# ## Cleaning

# %%
df.dropna(subset=['funder', 'scheme_management', 'public_meeting', 'permit', 'installer'], inplace=True)

# %% [markdown]
# ---
# ## Pseudo-engineering

# %%
df['age'] = (2020 - df.construction_year)
d = {2020:np.NaN}
df.age.replace(d,inplace=True)
nancounts = df.age.isna().sum() #to get count of NaNs being replaced
df.age = df.age.fillna(df.age.mean())

# %%
df.population.astype('int64')
df.age = df.age.astype('int64')

# %%
df.status_group.value_counts()
# Out:
# functional                 26720
# non functional             18432
# functional needs repair     3499
# Name: status_group, dtype: int64

# %% [markdown]
# ---
# ## Drop features

# %%
df = df.drop(columns=['id','source_type','payment','recorded_by','construction_year',  
                      'date_recorded','quality_group','quantity_group','waterpoint_type_group', 
                      'num_private','district_code','region_code','extraction_type','extraction_type_group',
                      'subvillage','wpt_name','scheme_name','management_group'],axis=1)

# %% [markdown]
# ---
# ## Review cleaned set

# %%
#df.head()
# Out:
#      status_group  amount_tsh               funder  gps_height     installer  \
# 0      functional      6000.0                Roman        1390         Roman
# 2      functional        25.0         Lottery Club         686  World vision
# 3  non functional         0.0               Unicef         263        UNICEF
# 5      functional        20.0  Mkinga Distric Coun           0           DWE
# 6  non functional         0.0                 Dwsp           0          DWSP
#
#    longitude   latitude                    basin     region              lga  \
# 0  34.938093  -9.856322               Lake Nyasa     Iringa           Ludewa
# 2  37.460664  -3.821329                  Pangani    Manyara        Simanjiro
# 3  38.486161 -11.155298  Ruvuma / Southern Coast     Mtwara         Nanyumbu
# 5  39.172796  -4.765587                  Pangani      Tanga           Mkinga
# 6  33.362410  -3.766365                 Internal  Shinyanga  Shinyanga Rural
#
# ...

# %%
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48651 entries, 0 to 59399
# Data columns (total 24 columns):
# status_group             48651 non-null object
# amount_tsh               48651 non-null float64
# funder                   48651 non-null object
# gps_height               48651 non-null int64
# installer                48651 non-null object
# longitude                48651 non-null float64
# latitude                 48651 non-null float64
# basin                    48651 non-null object
# region                   48651 non-null object
# lga                      48651 non-null object
# ward                     48651 non-null object
# population               48651 non-null int64
# public_meeting           48651 non-null object
# scheme_management        48651 non-null object
# permit                   48651 non-null object
# extraction_type_class    48651 non-null object
# management               48651 non-null object
# payment_type             48651 non-null object
# ...

# %%
#df.describe(include='all').T
# Out:
#                        count unique                     top   freq     mean  \
# status_group           48651      3              functional  26720      NaN
# amount_tsh             48651    NaN                     NaN    NaN  357.728
# funder                 48651   1588  Government Of Tanzania   8147      NaN
# gps_height             48651    NaN                     NaN    NaN  696.308
# installer              48651   1799                     DWE  14670      NaN
# longitude              48651    NaN                     NaN    NaN  34.2314
# latitude               48651    NaN                     NaN    NaN  -5.7035
# basin                  48651      9                 Pangani   8540      NaN
# region                 48651     21                  Iringa   5220      NaN
# lga                    48651    118                  Njombe   2455      NaN
# ward                   48651   1875                   Igosi    305      NaN
# ...

# %%
df.to_csv('data/cleaned_water_EDA.csv')

# %% [markdown]
# ## Re-balance Classes

# %%
#define classes
df['status_group'] = df['status_group'].replace(to_replace =["functional needs repair", "non functional"],value ="needs repair")
df['status_group'] = df['status_group'].map({'functional': 0, 'needs repair': 1})

# %%
df = df.drop(columns=['latitude','longitude'])#,'amount_tsh','gps_height','population'])

# %%
df.to_csv('data/cleaned_water_Modeling.csv')
